# %%
# Imports
import pandas as pd
import numpy as np
from sklearn import datasets ## imports datasets from scikit-learn

# Plotting
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../../datasets/parking_birmingham.csv")
df.head()
# Out:
#   SystemCodeNumber  Capacity  Occupancy          LastUpdated
# 0      BHMBCCMKT01       577         61  2016-10-04 07:59:42
# 1      BHMBCCMKT01       577         64  2016-10-04 08:25:42
# 2      BHMBCCMKT01       577         80  2016-10-04 08:59:42
# 3      BHMBCCMKT01       577        107  2016-10-04 09:32:46
# 4      BHMBCCMKT01       577        150  2016-10-04 09:59:48

# %%
# Get a general view of the dataset
df.plot(figsize=(18,5))

# %%
# Check for null values
if(df.isnull().values.any() == False):
    print("Dataset has no null values..")
# Out:
# Dataset has no null values..

# %%
# Check 
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000395BBEC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000039587A2B0>]], dtype=object)

# %%
capacity_mean = df['Capacity'].mean()
occupancy_mean = df['Occupancy'].mean()
print(capacity_mean, occupancy_mean)
# Out:
# 1397.5501301901056 642.2289106027941
